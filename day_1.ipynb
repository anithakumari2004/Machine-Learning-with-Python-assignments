# %% [markdown]
# BESANT TECHNOLOGIES

# %% [raw]
# dfnb
# thjm
# uytfgn
# fgbn
# tghnm

# %%
print("good afternoon")
# Out:
# good afternoon

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print("hi,good afternoon all")
# Out:
# hi,good afternoon all

# %%
names="Anita"
print("Hi!",names,"Good Afternoon")
# Out:
# Hi! Anita Good Afternoon

# %%
name="Muskan"
print("Hii! {} Good Afternoon".format(name))
# Out:
# Hii! Muskan Good Afternoon

# %%
name = "Anita"
print(f"Hii {name} good afternoon")
# Out:
# Hii Anita good afternoon

# %%
#read 2 values from users ansd perform addition
X = input("Enter a value")
Y = input("Enter another Value")
S = X+Y
print("The sum is:",S)
# Out:
# Enter a value 5
# Enter another Value 8
# The sum is: 58

# %%
X = int(input("Enter a value"))
Y = int(input("Enter another Value"))
S = X+Y
print("The sum is:",S)
# Out:
# Enter a value 6
# Enter another Value 5
# The sum is: 11

# %%
X = int(input("Enter a value"))
Y = int(input("Enter another Value"))
S = X+Y
print(f"The sum of {X} and {Y} is:",S)
# Out:
# Enter a value 5
# Enter another Value 8
# The sum of 5 and 8 is: 13

# %%
# Write a program to calculate Area of rectangle
l=float(input("Enter length of the Rectangle:"))
b=float(input("Enter breadth of the Rectangle:"))
Area =l*b
print("Area of Rectangle is:",Area)
print(f"Area of Rectangle is {Area}")
# Out:
# Enter length of the Rectangle: 34
# Enter breadth of the Rectangle: 43
# Area of Rectangle is: 1462.0
# Area of Rectangle is 1462.0

# %% [markdown]
# VAREABLES:
# they store the any values
#
# * Valid variable declarations
#   a=43
#   A = 22
#   num = 78
#   num1 = 1234
#   Num2 = 065
#   stu_name ="Anita"
#   _std_id = 1000
#
# * Invalid variable declarations
#   2num = 456
#   std email = "asdf@gmail.com"
#   stu*place = "Muzaffarpur"

# %%
#Add two numbers 
# then multiply by 10
# then divide by 5
# then subtract with 3
# then square the value

a = 5
b = 2
c= a+b
d = c*10
e = d/5
f = e-3
square = f*f
print(square)
# Out:
# 121.0

# %% [markdown]
# # Read stu name,stu id and three subject marks for each 100 and display the result
# *******Student Details********
# stu name : Anita
# stu id : 1000
# s1 : 91
# s2 : 87
# s3 : 85
# total:
# per:
# *********All the Best********

# %%
stu_name = input("Enter Student Name:")
stu_id = int(input("Enter student id:"))
S1 = int(input("Enter subject one marks:"))
S2 = int(input("Enter 2nd subject marks:"))
S3 = int(input("Enter 3rd subject marks:"))
total = S1+S2+S3
per = total/3
print(total)
print(per)
# Out:
# Enter Student Name: Anita
# Enter student id: 345
# Enter subject one marks: 91
# Enter 2nd subject marks: 87
# Enter 3rd subject marks: 85
# 263
# 87.66666666666667

# %% [raw]
# Data Types : It will represent the type of data
# single valued data types
# int
# float
# str
# bool
# complex
#
# Multivalued data types
# list
# tuple
# set
# dict

# %%
a = 5
type(a)
# Out:
# int

# %%
b = 1,7
type(b)
# Out:
# tuple

# %%
Operators
Its Special symbols perform specific task b/w two operands is called operator
3+9
3,9 = operands
+ -> operator
Types of operator in python
1) Arithmatic operator : + - * / % // **
2)Assignment operator: = += -= *= %= /=  //= **=
3) logical operator : and, or, not
4)Relational operator: > < >= <= == !=
5)Bitwise operator : & | ~ >> < 
6)Identity operator:
7)membership operator:
# Out:
#   Cell In[16], line 7
#     1) Arithmatic operator : + - * / % // **
#      ^
# SyntaxError: unmatched ')'

# %%
+
