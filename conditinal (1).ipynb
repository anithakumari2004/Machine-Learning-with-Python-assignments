# %%
conditional statements in python are used to make decision based on conditions(true/false). They control the flow of your program

types of conditional statements
1) if
2) if else
3) if else ladder/ contineous if else
4) nested if else

# %%
if syntax
if condition:
    statements

# %%
age = 29
country = "India"
if (age >=18 and country =="India"):
    print("eligible for voting")
# Out:
# eligible for voting

# %%
if else statement 
if condition:
    statement of if
else:
    statement of else

# %%
age = 2
country = "India"
if (age >=18 and country =="India"):
    print("eligible for voting")
else:
    print("Not eligible for voting")
# Out:
# Not eligible for voting

# %%
# write a program to check given numner is even or odd 
num = int(input("Enter a number:"))
if num%2==0:
    print("Number is Even")
else:
    print("Number is Odd")
# Out:
# Enter a number: 7
# Number is Odd

# %%
# write a program to check the given nuber is positive ,zero , negative

if else ladder / contineuos if else syntax 


if condition1:
    statement of condition1
    else:
        if condition2:
            statements of cond2
        else:
            if condition3:
                statement of condition 3
            ....
        else:
            default statements

if condion1:
    statement of condition1
elif condition2:
    statement of condition2
elif condition3:
    statement of condition3
    ......
else:
   default statements

# %%
n = int(input("enter a number"))
if n==0:
    print(n,"is zero")
elif n>0:
    print(n,"is positive")
else:
    print(n,"is negative")
# Out:
# enter a number 5
# 5 is positive

# %%
#based on percentage print the result 
85% - 100% => distinction
60% - 84% => 1st class
50% - 59% => second class
.35% -49% => just pass
<=35% => fail

# %%
marks = int(input("enter the marks in percentage:"))
if(marks<0 or marks>100):
    print("invalid")
elif(marks>=85):
    print("Distinct")
elif(marks>=60 and marks<=84):
    print("1st class")
elif(marks>=50 and marks<=59):
    print("second class")
elif(marks>=35 and marks<=49):
    print("just pass")
else:
    print("Fail")
# Out:
# enter the marks in percentage: 67
# 1st class

# %%
# check the given inputs that form which type of triangle
# equilateral
# isosceles
# scalene

a = float(input("Enter first side"))
b = float(input("Enter second side"))
c = float(input("Enter third side"))
if ( a == b and b==c and c==a):
    print(" Its equilateral traingle")
elif(a==b or b==c or c==a):
    print("its isosceles traingle")
else:
    print("its scalene traingle")
# Out:
# Enter first side 4
# Enter second side 5
# Enter third side 5
# its isosceles traingle

# %%
1. E-commerce Discount Calculator

Scenario: An online store offers discounts based on the purchase amount:

10% discount for purchases between $100 and $500

20% discount for purchases above $500

No discount for purchases below $100


Task: Write a program that takes the purchase amount as input and calculates the discount and final amount to be paid.

# %%
amount = float(input("Enter purchase amount: "))
if 100 <= amount <= 500:
    discount = amount * 0.10
elif amount > 500:
    discount = amount * 0.20
else:
    discount = 0
final_amount = amount - discount
print("Discount:", discount)
print("Final Amount to Pay:", final_amount)
# Out:
# Enter purchase amount:  400
# Discount: 40.0
# Final Amount to Pay: 360.0

# %%
2. Traffic Light Simulation

Scenario: Create a program that simulates a traffic light. The user inputs one of the colors: Red, Yellow, or Green. Based on the input:

If the input is Red, display "Stop."

If the input is Yellow, display "Ready to move."

If the input is Green, display "Go."

For invalid input, display "Invalid color."

# %%
color = input("Enter traffic light color (Red/Yellow/Green): ")
if color == "red":
    print("Stop.")
elif color == "yellow":
    print("Ready to move.")
elif color == "green":
    print("Go.")
else:
    print("Invalid color.")
# Out:
# Enter traffic light color (Red/Yellow/Green):  red
# Stop.

# %%
3. Grade Evaluation System

Scenario: A school uses the following grading system:

Marks >= 90: Grade A

Marks >= 75 and < 90: Grade B

Marks >= 50 and < 75: Grade C

Marks < 50: Fail


Task: Write a program that accepts the student's marks and displays their grade.

# %%
marks = float(input("Enter marks: "))
if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks:  55
# Grade C

# %%
4. Odd or Even and Divisibility Check

Scenario: Write a program that takes an integer as input and checks:

Whether the number is odd or even

Whether the number is divisible by 5


Display appropriate messages for both conditions.

# %%
num = int(input("Enter a number: "))
# Odd or Even
if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Divisible by 5
if num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# Enter a number:  12
# Even number
# Not divisible by 5

# %%
5. Password Strength Checker

Scenario: Write a program that checks the strength of a password based on these rules:

Length >= 8 characters: Strong

Length between 5 and 7 characters: Medium

Length < 5 characters: Weak

# %%
password = input("Enter password: ")
length = len(password)
if length >= 8:
    print("Strong password")
elif 5 <= length <= 7:
    print("Medium password")
else:
    print("Weak password")
# Out:
# Enter password:  anita
# Medium password

# %%
6. Electricity Bill Calculator

Scenario: An electricity company charges its customers as follows:

First 100 units: $0.5 per unit

Next 100 units (101-200): $0.75 per unit

Above 200 units: $1 per unit


Task: Write a program that accepts the number of units consumed and calculates the total bill.

# %%
units = float(input("Enter units consumed: "))
if units <= 100:
    bill = units * 0.5
elif units <= 200:
    bill = (100 * 0.5) + (units - 100) * 0.75
else:
    bill = (100 * 0.5) + (100 * 0.75) + (units - 200) * 1

print("Total Electricity Bill:", bill)
# Out:
# Enter units consumed:  167
# Total Electricity Bill: 100.25

# %%
7. Eligibility for Loan Approval

Scenario: A bank approves loans based on these conditions:

Age should be between 21 and 60

Monthly income should be greater than or equal to $5000


Task: Write a program to check whether a person is eligible for the loan based on their age and monthly income.

# %%
age = int(input("Enter age: "))
income = float(input("Enter monthly income: "))
if 21 <= age <= 60 and income >= 5000:
    print("Eligible for loan")
else:
    print("Not eligible for loan")
# Out:
# Enter age:  45
# Enter monthly income:  4000
# Not eligible for loan

# %%
8. Temperature Alert System

Scenario: A weather monitoring system alerts based on the temperature:

Below 0°C: "Freezing weather"

0°C to 20°C: "Cold weather"

21°C to 30°C: "Warm weather"

Above 30°C: "Hot weather"


Task: Write a program that takes the temperature as input and displays the corresponding alert message.

# %%
temp = float(input("Enter temperature (°C): "))
if temp < 0:
    print("Freezing weather")
elif 0 <= temp <= 20:
    print("Cold weather")
elif 21 <= temp <= 30:
    print("Warm weather")
else:
    print("Hot weather")
